# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasJordi/analiseDeepinsight/blob/main/An%C3%A1lise_Deepinsight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+git://github.com/alok-ai-lab/DeepInsight.git#egg=DeepInsight

# %%
import pandas as pd, numpy as np
import math
import random
import pandas_datareader as web

from pyDeepInsight import ImageTransformer, LogScaler
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime

plt.style.use('fivethirtyeight')
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Abraçadeira

# %%
caminho=('/content/drive/MyDrive/sobressalentes/abraçadeira.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo'].values
X=df.drop(columns=['Consumo']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)

# %% [markdown]
# ## Barra

# %%
caminho=('/content/drive/MyDrive/sobressalentes/barra.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo(kg)'].values
X=df.drop(columns=['Consumo(kg)']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)

# %% [markdown]
# ## Bucha

# %%
caminho=('/content/drive/MyDrive/sobressalentes/bucha.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo'].values
X=df.drop(columns=['Consumo']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)

# %% [markdown]
# ## Cabo instrumentação

# %%
caminho=('/content/drive/MyDrive/sobressalentes/cabo instrumentação.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo'].values
X=df.drop(columns=['Consumo']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)

# %% [markdown]
# ## Gaxeta

# %%
caminho=('/content/drive/MyDrive/sobressalentes/gaxeta.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo'].values
X=df.drop(columns=['Consumo']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)

# %% [markdown]
# ## Rolamento

# %%
caminho=('/content/drive/MyDrive/sobressalentes/rolamento.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo'].values
X=df.drop(columns=['Consumo']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)

# %% [markdown]
# ## Selante

# %%
caminho=('/content/drive/MyDrive/sobressalentes/selante.csv')
df=pd.read_csv(caminho)
df=df.fillna(0)
#X=df.drop(columns=['Consumo']).values

Y=df['Consumo'].values
X=df.drop(columns=['Consumo']).values
#df.iloc[:, 1:].values
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1, random_state=42, )
X_train.shape


ln = LogScaler()
X_train_norm = ln.fit_transform(X_train)
X_test_norm = ln.transform(X_test)
it = ImageTransformer(feature_extractor='tsne', 
                      pixels=50, random_state=1701, 
                      n_jobs=-1)
plt.figure(figsize=(5, 5))
it.fit(X_train_norm, plot=True)

# %%
fdm = it.feature_density_matrix()
fdm[fdm == 0] = np.nan

plt.figure(figsize=(10, 7))

ax = sns.heatmap(fdm, cmap="viridis", linewidths=0.01, 
                 linecolor="lightgrey", square=True)
for _, spine in ax.spines.items():
    spine.set_visible(True)
